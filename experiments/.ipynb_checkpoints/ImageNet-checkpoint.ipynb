# %%
import dataclasses
from collections.abc import Iterator, Mapping
from types import MappingProxyType
from typing import Any, Literal, Optional

import jax
import jax.numpy as jnp
import sklearn
import sklearn.datasets

import optax

import matplotlib.pyplot as plt
from IPython.display import clear_output, display

from ott import datasets
from ott.geometry import costs, pointcloud

from ott.tools import sinkhorn_divergence

import jax
import jax.numpy as jnp
from ott.geometry.geometry import Geometry
from ott.problems.linear import linear_problem
from ott.solvers.linear import sinkhorn
import scipy
import numpy as np

from typing import Any, Optional

import matplotlib.pyplot as plt
from matplotlib import colors

from ott.geometry import costs, pointcloud
from ott.problems.linear import linear_problem, potentials
from ott.solvers import linear
from ott.tools import progot
import scipy

import pandas as pd
import scanpy as sc
import numpy as np
import torch
import sys
sys.path.insert(0, '../src/')
import importlib
import FRLC
from FRLC import FRLC_opt
import HR_OT
importlib.reload(HR_OT)

import torch.multiprocessing as mp

# %%
@jax.jit
def sinkhorn_loss(
    x: jnp.ndarray, y: jnp.ndarray, epsilon: float = 0.001
) -> float:
    """Computes transport between (x, a) and (y, b) via Sinkhorn algorithm."""
    a = jnp.ones(len(x)) / len(x)
    b = jnp.ones(len(y)) / len(y)
    
    _, out = sinkhorn_divergence.sinkhorn_divergence(
        pointcloud.PointCloud, x, y, epsilon=epsilon, a=a, b=b
    )
    
    return out.divergence


def run_progot(
    x: jnp.ndarray, y: jnp.ndarray, cost_fn: costs.TICost, **kwargs: Any
) -> progot.ProgOTOutput:
    geom = pointcloud.PointCloud(x, y, cost_fn=cost_fn)
    prob = linear_problem.LinearProblem(geom)
    estim = progot.ProgOT(**kwargs)
    out = estim(prob)
    return out

K = 4

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'On device: {device}')
dtype = torch.float64
# Out:
# On device: cuda

# %%
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Subset
import torch
import torchvision.models as models
import os

# Define image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images for CNN input
    transforms.ToTensor(),
])

# Load ImageNet dataset from extracted path # /ILSVRC/Data/CLS-LOC/test
imagenet_dataset = datasets.ImageFolder(root="/scratch/gpfs/DATASETS/imagenet/ilsvrc_2012_classification_localization/train",
                                        transform=transform)

# Create DataLoader for batching
imagenet_loader = DataLoader(imagenet_dataset, batch_size=32, shuffle=True, num_workers=4)

print(f"Loaded {len(imagenet_dataset)} images from ImageNet!")


model_path = os.path.expanduser("~/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth")

# Load pretrained ResNet model
model = models.resnet50()
model.load_state_dict(torch.load(model_path, map_location="cpu"))
model.fc = torch.nn.Identity()  # Remove classification layer to extract features
model.eval()  # Set to evaluation mode

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Compute embeddings
def extract_features(dataloader, model):
    embeddings = []
    num_img = 0
    with torch.no_grad():
        for idx, (images, _) in enumerate(dataloader):
            num_img += len(images)
            if idx % 100 == 0:
                print(f'image idx {idx}, images: {num_img}')
            images = images.to(device)
            features = model(images)
            embeddings.append(features.cpu().numpy())
    return np.vstack(embeddings)  # Stack all embeddings

print('extracting embeddings!')
embeddings = extract_features(imagenet_loader, model)

# %%
import pickle

save_dir = "/scratch/gpfs/ph3641/hr_ot/"

os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, "embeddings.pkl")

with open(save_path, "wb") as f:
    pickle.dump(embeddings, f)

print(f"Embeddings saved successfully to {save_path}")
# Out:
# '\nimport pickle\nsave_dir = "/scratch/gpfs/ph3641/hr_ot/"\n\nos.makedirs(save_dir, exist_ok=True)\nsave_path = os.path.join(save_dir, "embeddings.pkl")\n\nwith open(save_path, "wb") as f:\n    pickle.dump(embeddings, f)\n\nprint(f"Embeddings saved successfully to {save_path}")\n'

# %%
import pickle
emb_dir = '/scratch/gpfs/ph3641/hr_ot/embeddings.pkl'

# Load embeddings from the pickle file
with open(emb_dir, "rb") as f:
    embeddings = pickle.load(f)

print(f"Embeddings loaded successfully! Shape: {embeddings.shape}")
# Out:
# Embeddings loaded successfully! Shape: (1281167, 2048)

# %%
import rank_annealing

# 1. Making it even; remove 1 image
embeddings = embeddings[1:,:]

# 2. Get to a close even number which when divided is non-prime
print(f'num embeddings: {embeddings.shape[0]}')
N = embeddings.shape[0] // 2
q = 640500
k = (N-q)*2

embed_sliced = embeddings[:-k]
n = embed_sliced.shape[0] // 2
print(n)

rank_schedule = rank_annealing.optimal_rank_schedule( n , hierarchy_depth = 6, max_Q = int(2**11), max_rank = 64 )
print(rank_schedule)
# Out:
# num embeddings: 1281166
# 640500
# Optimized rank-annealing schedule: [7, 50, 1830]
# [7, 50, 1830]

# %%
import torch

num_samples = embed_sliced.shape[0]

# Shuffle indices
indices = torch.randperm(num_samples)

# Split into two tensors
X = embeddings[indices[:n]]  # First 50%
Y = embeddings[indices[n:]]  # Second 50%

print(f"X shape: {X.shape}, Y shape: {Y.shape}")
# Out:
# X shape: (640500, 2048), Y shape: (640500, 2048)

# %%
num_zero_rows = torch.sum(torch.sum(torch.tensor(embeddings), dim=1) == 0).item()
print(f"Number of all-zero rows: {num_zero_rows}")
# Out:
# Number of all-zero rows: 0

# %%
import math
import functools
import operator
import rank_annealing
importlib.reload(rank_annealing)
importlib.reload(HR_OT)

# Squared Euclidean cost p=2 or Euclidean if p=1
p = 1
K = 2

#sample_sizes = [int(2**i) for i in range(5, 18, 1)]

# Initialize dictionaries to store costs and sample sizes
costs = {
    'HROT_LR': {'samples': [], 'costs': []},
    'Sinkhorn': {'samples': [], 'costs': []},
    'ProgOT': {'samples': [], 'costs': []}
}

# Define pairwise Dist Mat
_X = torch.tensor(np.array(X)).float().to(device)
_Y = torch.tensor(np.array(Y)).float().to(device)

# hierarchy_depth=6, max_Q=int(2**10), max_rank=16 up to 131072 points
# hierarchy_depth=6, max_Q=int(2**10), max_rank=64 for 262144 + 524288 points
# hierarchy_depth=6, max_Q=int(2**10), max_rank=64 for 262144 + 524288 points
rank_schedule = rank_annealing.optimal_rank_schedule( X.shape[0] , hierarchy_depth = 6, max_Q = int(2**11), max_rank = 64 )
print(rank_schedule)

try:
    hrot_lr = HR_OT.HierarchicalRefinementOT.init_from_point_clouds(_X, _Y, rank_schedule, base_rank=1, device=device)
    del _X, _Y
    F = hrot_lr.run(return_as_coupling=False)
    cost_hrot_lr = hrot_lr.compute_OT_cost()
    print(f'HR-OT cost: {cost_hrot_lr}')
except Exception as e:
    print(f'HROT-LR failed for sample size {n}: {e}')
# Out:
# Optimized rank-annealing schedule: [7, 50, 1830]
# [7, 50, 1830]
# x0 shape: torch.Size([640500, 2048]), x1 shape: torch.Size([640500, 2048]), rankD: 7
# Iteration: 0
# x0 shape: torch.Size([91500, 2048]), x1 shape: torch.Size([91500, 2048]), rankD: 50
# Iteration: 0
# x0 shape: torch.Size([91500, 2048]), x1 shape: torch.Size([91500, 2048]), rankD: 50
# Iteration: 0
# x0 shape: torch.Size([91500, 2048]), x1 shape: torch.Size([91500, 2048]), rankD: 50
# Iteration: 0
# x0 shape: torch.Size([91500, 2048]), x1 shape: torch.Size([91500, 2048]), rankD: 50
# Iteration: 0
# x0 shape: torch.Size([91500, 2048]), x1 shape: torch.Size([91500, 2048]), rankD: 50
# Iteration: 0
# x0 shape: torch.Size([91500, 2048]), x1 shape: torch.Size([91500, 2048]), rankD: 50
# Iteration: 0
# x0 shape: torch.Size([91500, 2048]), x1 shape: torch.Size([91500, 2048]), rankD: 50
# Iteration: 0
# Last level, rank chunk-size 1830 with 350 iterations to completion.
# 0/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 1/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 2/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 3/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 4/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 5/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 6/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 7/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 8/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 9/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 10/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 11/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 12/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 13/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 14/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 15/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 16/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 17/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 18/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 19/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 20/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 21/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 22/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 23/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 24/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 25/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 26/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 27/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 28/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 29/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 30/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 31/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 32/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 33/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 34/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 35/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 36/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 37/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 38/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 39/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 40/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 41/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 42/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 43/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 44/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 45/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 46/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 47/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 48/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 49/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 50/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 51/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 52/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 53/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 54/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 55/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 56/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 57/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 58/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 59/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 60/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 61/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 62/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 63/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 64/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 65/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 66/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 67/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 68/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 69/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 70/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 71/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 72/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 73/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 74/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 75/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 76/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 77/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 78/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 79/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 80/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 81/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 82/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 83/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 84/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 85/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 86/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 87/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 88/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 89/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 90/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 91/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 92/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 93/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 94/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 95/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 96/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 97/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 98/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 99/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 100/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 101/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 102/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 103/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 104/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 105/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 106/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 107/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 108/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 109/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 110/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 111/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 112/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 113/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 114/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 115/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 116/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 117/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 118/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 119/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 120/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 121/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 122/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 123/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 124/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 125/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 126/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 127/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 128/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 129/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 130/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 131/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 132/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 133/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 134/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 135/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 136/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 137/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 138/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 139/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 140/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 141/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 142/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 143/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 144/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 145/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 146/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 147/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 148/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 149/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 150/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 151/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 152/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 153/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 154/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 155/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 156/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 157/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 158/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 159/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 160/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 161/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 162/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 163/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 164/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 165/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 166/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 167/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 168/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 169/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 170/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 171/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 172/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 173/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 174/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 175/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 176/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 177/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 178/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 179/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 180/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 181/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 182/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 183/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 184/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 185/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 186/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 187/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 188/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 189/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 190/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 191/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 192/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 193/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 194/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 195/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 196/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 197/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 198/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 199/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 200/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 201/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 202/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 203/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 204/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 205/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 206/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 207/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 208/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 209/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 210/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 211/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 212/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 213/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 214/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 215/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 216/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 217/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 218/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 219/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 220/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 221/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 222/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 223/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 224/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 225/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 226/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 227/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 228/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 229/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 230/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 231/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 232/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 233/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 234/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 235/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 236/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 237/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 238/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 239/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 240/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 241/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 242/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 243/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 244/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 245/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 246/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 247/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 248/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 249/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 250/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 251/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 252/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 253/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 254/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 255/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 256/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 257/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 258/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 259/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 260/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 261/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 262/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 263/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 264/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 265/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 266/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 267/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 268/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 269/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 270/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 271/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 272/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 273/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 274/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 275/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 276/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 277/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 278/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 279/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 280/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 281/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 282/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 283/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 284/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 285/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 286/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 287/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 288/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 289/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 290/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 291/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 292/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 293/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 294/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 295/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 296/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 297/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 298/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 299/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 300/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 301/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 302/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 303/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 304/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 305/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 306/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 307/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 308/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 309/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 310/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 311/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 312/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 313/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 314/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 315/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 316/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 317/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 318/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 319/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 320/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 321/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 322/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 323/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 324/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 325/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 326/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 327/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 328/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 329/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 330/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 331/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 332/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 333/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 334/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 335/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 336/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 337/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 338/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 339/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 340/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 341/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 342/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 343/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 344/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 345/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 346/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 347/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 348/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 349/350 of final-level iterations to completion
# x0 shape: torch.Size([1830, 2048]), x1 shape: torch.Size([1830, 2048]), rankD: 1830
# Iteration: 0
# Iteration: 25
# Iteration: 50
# HR-OT cost: 18.974472045898438

# %%
n = len(F)
mat = np.zeros((n, 2))

for k, (idx1, idx2) in enumerate(F):
    mat[k, 0] = idx1.cpu().numpy()
    mat[k, 1] = idx2.cpu().numpy()

np.save('/scratch/gpfs/ph3641/hr_ot/embedding_alignment.npy', mat)
# Out:
# /tmp/ipykernel_3377641/4293063376.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   mat[k, 0] = idx1.cpu().numpy()
# /tmp/ipykernel_3377641/4293063376.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   mat[k, 1] = idx2.cpu().numpy()

# %%
mat = np.load('/scratch/gpfs/ph3641/hr_ot/embedding_alignment.npy')
print(mat.shape)
# Out:
# (640500, 2)
