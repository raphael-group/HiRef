# %%
import dataclasses
from collections.abc import Iterator, Mapping
from types import MappingProxyType
from typing import Any, Literal, Optional

import jax
import jax.numpy as jnp
import sklearn
import sklearn.datasets

import optax

import matplotlib.pyplot as plt
from IPython.display import clear_output, display

from ott import datasets
from ott.geometry import costs, pointcloud

from ott.tools import sinkhorn_divergence

import jax
import jax.numpy as jnp
from ott.geometry.geometry import Geometry
from ott.problems.linear import linear_problem
from ott.solvers.linear import sinkhorn
import scipy
import numpy as np

from typing import Any, Optional

import matplotlib.pyplot as plt
from matplotlib import colors

from ott.geometry import costs, pointcloud
from ott.problems.linear import linear_problem, potentials
from ott.solvers import linear
from ott.tools import progot
import scipy

import pandas as pd
import scanpy as sc
import numpy as np
import torch
import sys
sys.path.insert(0, '../src/')
import importlib
import FRLC
from FRLC import FRLC_opt
import HR_OT
importlib.reload(HR_OT)

import torch.multiprocessing as mp

# %%
global n_points;
n_points = 512

# %%
def plot_eval_samples(
    eval_data_source, eval_data_target, transported_samples=None
):
    fig, axs = plt.subplots(
        1, 2, figsize=(8, 4), gridspec_kw={"wspace": 0, "hspace": 0}
    )
    axs[0].scatter(
        eval_data_source[:, 0],
        eval_data_source[:, 1],
        color="#A7BED3",
        s=10,
        alpha=0.5,
        label="source",
    )
    axs[0].set_title("Source measure samples")
    axs[1].scatter(
        eval_data_target[:, 0],
        eval_data_target[:, 1],
        color="#1A254B",
        s=10,
        alpha=0.5,
        label="target",
    )
    axs[1].set_title("Target measure samples")

    if transported_samples is not None:
        axs[1].scatter(
            transported_samples[:, 0],
            transported_samples[:, 1],
            color="#F2545B",
            s=10,
            alpha=0.5,
            label="pushforward of source",
        )

    fig.legend(
        **{
            "ncol": (3 if transported_samples is not None else 2),
            "loc": "upper center",
            "bbox_to_anchor": (0.5, 0.1),
            "edgecolor": "k",
        }
    )

    for ax in axs:
        ax.set_xticks([])
        ax.set_yticks([])

    return fig, ax

@dataclasses.dataclass
class MAFMoonSampler:
    size: int

    def __iter__(self):
        rng = jax.random.key(0)
        while True:
            rng, sample_key = jax.random.split(rng, 2)
            yield self._sample(sample_key, self.size)

    def _sample(self, key, batch_size):
        x = jax.random.normal(key, shape=[batch_size, 2])
        x = x.at[:, 0].add(x[:, 1] ** 2)
        x = x.at[:, 0].mul(0.5)
        x = x.at[:, 0].add(-5)
        return x


@dataclasses.dataclass
class RingSampler:
    size: int

    def __iter__(self):
        rng = jax.random.key(0)
        while True:
            rng, sample_key = jax.random.split(rng, 2)
            yield self._sample(sample_key, self.size)

    def _sample(self, key, batch_size):
        n_samples4 = n_samples3 = n_samples2 = batch_size // 4
        n_samples1 = batch_size - n_samples4 - n_samples3 - n_samples2

        linspace4 = jnp.linspace(0, 2 * jnp.pi, n_samples4, endpoint=False)
        linspace3 = jnp.linspace(0, 2 * jnp.pi, n_samples3, endpoint=False)
        linspace2 = jnp.linspace(0, 2 * jnp.pi, n_samples2, endpoint=False)
        linspace1 = jnp.linspace(0, 2 * jnp.pi, n_samples1, endpoint=False)

        circ4_x = jnp.cos(linspace4) * 1.2
        circ4_y = jnp.sin(linspace4) * 1.2
        circ3_x = jnp.cos(linspace4) * 0.9
        circ3_y = jnp.sin(linspace3) * 0.9
        circ2_x = jnp.cos(linspace2) * 0.55
        circ2_y = jnp.sin(linspace2) * 0.55
        circ1_x = jnp.cos(linspace1) * 0.25
        circ1_y = jnp.sin(linspace1) * 0.25

        X = (
            jnp.vstack(
                [
                    jnp.hstack([circ4_x, circ3_x, circ2_x, circ1_x]),
                    jnp.hstack([circ4_y, circ3_y, circ2_y, circ1_y]),
                ]
            ).T
            * 3.0
        )
        X = sklearn.utils.shuffle(X)

        # Add noise
        X = X + jax.random.normal(key, shape=X.shape) * 0.08

        return X.astype("float32")

@dataclasses.dataclass
class SklearnDistribution:
    name: Literal["moon", "s_curve"]
    theta_rotation: float = 0.0
    mean: Optional[jnp.ndarray] = None
    noise: float = 0.01
    scale: float = 1.0
    batch_size: int = 1024
    rng: Optional[jax.Array] = None

    def __iter__(self) -> Iterator[jnp.ndarray]:
        return self._create_sample_generators()

    def _create_sample_generators(self) -> Iterator[jnp.ndarray]:
        rng = jax.random.key(0) if self.rng is None else self.rng
        rotation = jnp.array(
            [
                [jnp.cos(self.theta_rotation), -jnp.sin(self.theta_rotation)],
                [jnp.sin(self.theta_rotation), jnp.cos(self.theta_rotation)],
            ]
        )
        while True:
            rng, _ = jax.random.split(rng)
            seed = jax.random.randint(rng, [], minval=0, maxval=1e5).item()
            if self.name == "moon":
                samples, _ = sklearn.datasets.make_moons(
                    n_samples=(self.batch_size, 0),
                    random_state=seed,
                    noise=self.noise,
                )
            elif self.name == "s_curve":
                x, _ = sklearn.datasets.make_s_curve(
                    n_samples=self.batch_size,
                    random_state=seed,
                    noise=self.noise,
                )
                samples = x[:, [2, 0]]
            else:
                raise NotImplementedError(
                    f"SklearnDistribution `{self.name}` not implemented."
                )

            samples = jnp.asarray(samples, dtype=jnp.float32)
            samples = jnp.squeeze(jnp.matmul(rotation[None, :], samples.T).T)
            mean = jnp.zeros(2) if self.mean is None else self.mean
            samples = mean + self.scale * samples
            yield samples


def create_samplers(
    source_kwargs: Mapping[str, Any] = MappingProxyType({}),
    target_kwargs: Mapping[str, Any] = MappingProxyType({}),
    train_batch_size: int = 512,
    valid_batch_size: int = 512,
    rng: Optional[jax.Array] = None,
):
    rng = jax.random.key(0) if rng is None else rng
    rng1, rng2, rng3, rng4 = jax.random.split(rng, 4)
    train_dataset = datasets.Dataset(
        source_iter=iter(
            SklearnDistribution(
                rng=rng1, batch_size=train_batch_size, **source_kwargs
            )
        ),
        target_iter=iter(
            SklearnDistribution(
                rng=rng2, batch_size=train_batch_size, **target_kwargs
            )
        ),
    )
    valid_dataset = datasets.Dataset(
        source_iter=iter(
            SklearnDistribution(
                rng=rng3, batch_size=valid_batch_size, **source_kwargs
            )
        ),
        target_iter=iter(
            SklearnDistribution(
                rng=rng4, batch_size=valid_batch_size, **target_kwargs
            )
        ),
    )
    dim_data = 2
    return train_dataset, valid_dataset, dim_data

def ret_pts(experiment, n_points = 512):
    if experiment == 'checkerboard':
    
        num_samples_visualize = n_points
        (
            train_dataloaders,
            valid_dataloaders,
            input_dim,
        ) = datasets.create_gaussian_mixture_samplers(
            name_source="square_five",
            name_target="square_four",
            valid_batch_size=num_samples_visualize,
            train_batch_size=2048,
        )
        
        eval_data_source = next(valid_dataloaders.source_iter)
        eval_data_target = next(valid_dataloaders.target_iter)
        
        eval_data_source = next(valid_dataloaders.source_iter)
        eval_data_target = next(valid_dataloaders.target_iter)
    
    elif experiment == 'maf_moon_ring':
        
        train_loader = datasets.Dataset(
        source_iter=iter(MAFMoonSampler(size=n_points)),
        target_iter=iter(RingSampler(size=n_points)),
        )
        valid_loader = train_loader
        
        eval_data_source = next(train_loader.source_iter)
        eval_data_target = next(train_loader.target_iter)
    
    elif experiment == 'halfmoon_Scurve':
    
        train_dataset, valid_dataset, dim_data = create_samplers(
        source_kwargs={
            "name": "moon",
            "theta_rotation": jnp.pi / 6,
            "mean": jnp.array([0.0, -0.5]),
            "noise": 0.05,
        },
        target_kwargs={
            "name": "s_curve",
            "scale": 0.6,
            "mean": jnp.array([0.5, -2.0]),
            "theta_rotation": -jnp.pi / 6,
            "noise": 0.05,
            },
            train_batch_size=n_points,
            valid_batch_size=n_points)
        eval_data_source = next(train_dataset.source_iter)
        eval_data_target = next(train_dataset.target_iter)

    return eval_data_source, eval_data_target

# %%
@jax.jit
def sinkhorn_loss(
    x: jnp.ndarray, y: jnp.ndarray, epsilon: float = 0.001
) -> float:
    """Computes transport between (x, a) and (y, b) via Sinkhorn algorithm."""
    a = jnp.ones(len(x)) / len(x)
    b = jnp.ones(len(y)) / len(y)
    
    _, out = sinkhorn_divergence.sinkhorn_divergence(
        pointcloud.PointCloud, x, y, epsilon=epsilon, a=a, b=b
    )
    
    return out.divergence


def run_progot(
    x: jnp.ndarray, y: jnp.ndarray, cost_fn: costs.TICost, **kwargs: Any
) -> progot.ProgOTOutput:
    geom = pointcloud.PointCloud(x, y, cost_fn=cost_fn)
    prob = linear_problem.LinearProblem(geom)
    estim = progot.ProgOT(**kwargs)
    out = estim(prob)
    return out

K = 4
cost_fn = costs.SqEuclidean()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'On device: {device}')

dtype = torch.float64

# %%
def plot_proj(P):
    
    if isinstance(P, torch.Tensor):
        P = P.cpu().numpy()
    
    opt_target = np.diag(1 / np.sum(P, axis=1)) @ P @ Y
    for idx1 in range(P.shape[0]):
        x_values = X[idx1, 0], opt_target[idx1, 0]
        y_values = X[idx1, 1], opt_target[idx1, 1]
        plt.plot(x_values, y_values, c='black', linewidth=0.8, alpha=0.8)
    
    plt.scatter(X[:, 0], X[:, 1], c='b', label='Initial Points (Source)', alpha=0.7)
    plt.scatter(Y[:, 0], Y[:, 1], c='r', label='Final Points (Target)', alpha=0.7)
    plt.scatter(opt_target[:, 0], opt_target[:, 1], c='gold', label='Optimal Map', alpha=0.7)
    
    plt.show()

# %%
importlib.reload(HR_OT)
import objective_grad
import util
importlib.reload(FRLC)
importlib.reload(objective_grad)
importlib.reload(util)

sample_sizes = [int(2**i) for i in range(18, 21, 1)] # 5, 18, 1

experiment = 'halfmoon_Scurve' #'checkerboard'#'halfmoon_Scurve' #'maf_moon_ring'
plot_pts =  False

cost_list_hrot = []
cost_list_hrot_lr = []
cost_list_sinkhorn = []
cost_list_progOT = []

# %% [markdown]
# $$
# \text{dp}(d, t)
# \;=\;
# \min_{\substack{\prod_{j=1}^{t}x_j = d \\ 1 \le x_j \le C}}
# \;\sum_{j=1}^{t}\Bigl(\prod_{i=1}^{j}x_i\Bigr).
# $$
#
# $$
# \underbrace{r}{\text{first partial product}}
# \;+\;
# \underbrace{r \cdot \Bigl( |\sum{j=1}^{t-1} \prod_{i=1}^{j} x_{i+1} \Bigr) }_{\text{contribution of the next }(t-1)\text{ factors, each multiplied by }r}.
# $$

# %%
from functools import reduce

def min_sum_partial_products_with_factors(n, k, C):
    INF = float('inf')
    
    # dp[d][t] = minimal sum of partial products 
    #            if we want exactly t factors (each ≤ C) with product d.
    dp = [[INF]*(k+1) for _ in range(n+1)]
    
    # choice[d][t] = which first factor 'r' gave the optimal dp[d][t].
    choice = [[-1]*(k+1) for _ in range(n+1)]
    
    # Base case: t=1
    for d in range(1, n+1):
        if d <= C:
            dp[d][1] = d
            choice[d][1] = d  # the only factor is d itself
    
    # Fill dp for t = 2 .. k
    for t in range(2, k+1):
        for d in range(1, n+1):
            if dp[d][t-1] == INF and t > 1:
                # if dp[d][t-1] is already INF, no point continuing,
                # but we still need to check all possible r because
                # the product changes from d/r.
                pass
            # Try all possible r ≤ C that divide d
            for r in range(1, min(C,d)+1):
                if d % r == 0:
                    candidate = r + r * dp[d // r][t-1]
                    if candidate < dp[d][t]:
                        dp[d][t] = candidate
                        choice[d][t] = r
    
    # If dp[n][k] is INF, no valid factorization exists
    if dp[n][k] == INF:
        return None, []
    
    # Reconstruct the chosen factors from 'choice'
    factors = []
    d_cur, t_cur = n, k
    
    while t_cur > 0:
        r_cur = choice[d_cur][t_cur]
        factors.append(r_cur)
        d_cur //= r_cur
        t_cur -= 1
    
    return dp[n][k], factors

def factors(n):
    # Return list of all factors of an integer
    return set(reduce(
        list.__add__,
        ([i, n//i] for i in range(1, int(n**0.5) + 1) if n % i == 0)))

def max_factor_lX(n, max_X):
    factor_lst = factors(n)
    max_factor = 0
    for factor in factor_lst:
        if factor > max_factor and factor < max_X:
            max_factor = factor
    return max_factor

def optimal_rank_schedule(n, hierarchy_depth=6, max_Q=int(2**10), max_rank=16):
    Q = max_factor_lX(n, max_Q)
    ndivQ = int(n / Q)
    min_value, rank_schedule = min_sum_partial_products_with_factors(ndivQ, hierarchy_depth, max_rank)
    rank_schedule.sort()
    rank_schedule.append(Q)
    rank_schedule = [x for x in rank_schedule if x != 1]
    
    print(f'Optimized rank-annealing schedule: { rank_schedule }')
    
    assert functools.reduce(operator.mul, rank_schedule) == n, "Error! Rank-schedule does not factorize n!"
    '''
    RS = torch.tensor(rank_schedule)[:-1]
    print(RS)
    print(torch.cumprod(RS))
    LR_runs = torch.cumsum(torch.cumprod(RS)).sum() + 1
    print(f'Runs required before terminal Q-size case: {LR_runs}')
    '''    
    return rank_schedule
    
'''
def get_maxQK(n, maxQ, maxK):
    maxQ_factor = max_factor_lX(n, max_Q)
    ndivQ = int( n/Q )
    maxK_factor = max_factor_lX(ndivQ, maxK)
    return maxQ_factor, maxK_factor
'''

# %%
def plot_proj_monge(Monge_pair, X, Y):
    
    for idx1, idx2 in Monge_pair:
        idx1, idx2 = int(idx1), int(idx2)
        x_values = X[idx1, 0], Y[idx2, 0]
        y_values = X[idx1, 1], Y[idx2, 1]
        plt.plot(x_values, y_values, c='black', linewidth=0.8, alpha=0.8)
    
    plt.scatter(X[:, 0], X[:, 1], c='b', label='Initial Points (Source)', alpha=0.7)
    plt.scatter(Y[:, 0], Y[:, 1], c='r', label='Final Points (Target)', alpha=0.7)
    
    plt.show()

# %%
print(sample_sizes)

# %%
import math
import functools
import operator
import time

# Squared Euclidean cost p=2 or Euclidean if p=1
p = 1
K = 2

sample_sizes = [int(2**i) for i in range(15, 18, 1)]

# Initialize dictionaries to store costs and sample sizes
costs = {
    'HROT_LR': {'samples': [], 'costs': []},
    'Sinkhorn': {'samples': [], 'costs': []},
    'ProgOT': {'samples': [], 'costs': []}
}
'''
costs = {
    'HROT': {'samples': [], 'costs': []},
    'HROT_LR': {'samples': [], 'costs': []},
    'Sinkhorn': {'samples': [], 'costs': []},
    'ProgOT': {'samples': [], 'costs': []}
}
'''

for n in sample_sizes:
    
    print(f'Current sample size: {n}')
    X, Y = ret_pts( experiment,
                   n_points=n )
    
    # Define pairwise Dist Mat
    _X = torch.tensor(np.array(X)).float().to(device)
    _Y = torch.tensor(np.array(Y)).float().to(device)
    
    '''
    i = int( math.log( int( n / Q ) , K ) )
    rank_schedule = [K]*i
    rank_schedule.append(Q)
    '''
    # hierarchy_depth=6, max_Q=int(2**10), max_rank=16 up to 131072 points
    # hierarchy_depth=6, max_Q=int(2**10), max_rank=64 for 262144 points
    rank_schedule = optimal_rank_schedule( n, hierarchy_depth = 6, max_Q = int(2**10), max_rank = 64 )
    
    #rank_schedule = [K, int(n / K)]  # Total of (1+K) runs of low-rank OT req'd
    
    try:
        hrot_lr = HR_OT.HierarchicalRefinementOT.init_from_point_clouds(_X, _Y, rank_schedule, base_rank=1, device=device, sq_Euclidean=True)
        del _X, _Y
        s = time.time()
        F = hrot_lr.run(return_as_coupling=False)
        e = time.time()
        print(f'runtime: { e - s}')
        #plot_proj_monge(F, X, Y)
        cost_hrot_lr = hrot_lr.compute_OT_cost()
        costs['HROT_LR']['samples'].append(n)
        costs['HROT_LR']['costs'].append(cost_hrot_lr.item())
    except Exception as e:
        print(f'HROT-LR failed for sample size {n}: {e}')

    '''
    try:
        C = torch.cdist(_X, _Y) ** p
    except Exception as e:
        print(f'Failed to load cost mat for sample size {n}: {e}')
        continue'''
    
    # HROT
    '''
    try:
        hrot = HR_OT.HierarchicalRefinementOT(C, rank_schedule, base_rank=1, device=device)
        F = hrot.run(return_as_coupling=False)
        cost_hrot = hrot.compute_OT_cost()
        costs['HROT']['samples'].append(n)
        costs['HROT']['costs'].append(cost_hrot.item())
    except Exception as e:
        print(f'HROT failed for sample size {n}: {e}')
    '''
    '''
    # Sinkhorn 
    try:
        geom = Geometry(C.cpu().numpy())
        ot_problem = linear_problem.LinearProblem(geom)
        solver = sinkhorn.Sinkhorn()
        ot_solution = solver(ot_problem)
        P_sinkhorn = ot_solution.matrix
        e = time.time()
        print(f'Sinkhorn runtime: {e - s}')
        cost_sink = (C.cpu().numpy() * P_sinkhorn).sum()
        costs['Sinkhorn']['samples'].append(n)
        costs['Sinkhorn']['costs'].append(cost_sink)
    except Exception as e:
        print(f'Sinkhorn failed for sample size {n}: {e}')'''
    '''
    # ProgOT 
    try:
        x_train, y_train = X, Y
        alphas = progot.get_alpha_schedule("exp", num_steps=K)
        out = run_progot(X, Y, cost_fn, alphas=alphas, epsilons=None)
        P_progOT_default = out.get_output(-1).matrix
        cost_progOT = (C.cpu().numpy() * P_progOT_default).sum()
        costs['ProgOT']['samples'].append(n)
        costs['ProgOT']['costs'].append(cost_progOT)
    except Exception as e:
        print(f'ProgOT failed for sample size {n}: {e}')'''
    
    # Optionally, print the costs for successful methods
    print("Current Costs:")
    for method in costs:
        if costs[method]['samples'] and costs[method]['samples'][-1] == n:
            print(f"  {method}: {costs[method]['costs'][-1]}")
# Out:
# Current sample size: 32768
# Optimized rank-annealing schedule: [64, 512]
# x0 shape: torch.Size([32768, 2]), x1 shape: torch.Size([32768, 2]), rankD: 64
# Iteration: 0
# Iteration: 25
# Last level, rank chunk-size 512 with 64 iterations to completion.
# 0/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 1/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 2/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 3/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 4/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 5/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 6/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 7/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 8/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 9/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 10/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 11/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 12/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 13/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 14/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 15/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 16/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 17/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 18/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 19/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 20/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 21/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 22/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 23/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 24/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 25/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 26/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 27/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 28/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 29/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 30/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 31/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 32/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 33/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 34/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 35/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 36/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 37/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 38/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 39/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 40/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 41/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 42/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 43/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 44/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 45/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 46/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 47/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 48/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 49/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 50/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 51/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 52/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 53/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 54/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 55/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 56/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 57/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 58/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 59/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 60/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 61/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 62/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 63/64 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# runtime: 383.44355726242065
# Current Costs:
#   HROT_LR: 2.249025583267212
# Current sample size: 65536
# Optimized rank-annealing schedule: [2, 64, 512]
# x0 shape: torch.Size([65536, 2]), x1 shape: torch.Size([65536, 2]), rankD: 2
# Iteration: 0
# x0 shape: torch.Size([32768, 2]), x1 shape: torch.Size([32768, 2]), rankD: 64
# Iteration: 0
# Iteration: 25
# Iteration: 50
# x0 shape: torch.Size([32768, 2]), x1 shape: torch.Size([32768, 2]), rankD: 64
# Iteration: 0
# Iteration: 25
# Last level, rank chunk-size 512 with 128 iterations to completion.
# 0/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 1/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 2/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 3/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 4/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 5/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 6/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 7/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 8/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 9/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 10/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 11/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 12/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 13/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 14/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 15/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 16/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 17/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 18/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 19/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 20/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 21/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 22/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 23/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 24/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 25/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 26/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 27/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 28/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 29/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 30/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 31/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 32/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 33/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 34/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 35/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 36/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 37/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 38/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 39/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 40/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 41/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 42/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 43/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 44/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 45/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 46/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 47/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 48/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 49/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 50/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 51/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 52/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 53/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 54/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 55/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 56/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 57/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 58/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 59/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 60/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 61/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 62/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 63/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 64/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 65/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 66/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 67/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 68/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 69/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 70/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 71/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 72/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 73/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 74/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 75/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 76/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 77/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 78/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 79/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 80/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 81/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 82/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 83/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 84/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 85/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 86/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 87/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 88/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 89/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 90/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 91/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 92/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 93/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 94/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 95/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 96/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 97/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 98/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 99/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 100/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 101/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 102/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 103/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 104/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 105/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 106/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 107/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 108/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 109/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 110/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 111/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 112/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 113/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 114/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# 115/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 116/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 117/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 118/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 119/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 120/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 121/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 122/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 123/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 124/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 125/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# 126/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# 127/128 of final-level iterations to completion
# x0 shape: torch.Size([512, 2]), x1 shape: torch.Size([512, 2]), rankD: 512
# Iteration: 0
# Iteration: 25
# Iteration: 50
# runtime: 664.1615333557129
# Current Costs:
#   HROT_LR: 2.2453038692474365
# Current sample size: 131072
# Optimized rank-annealing schedule: [4, 64, 512]
# x0 shape: torch.Size([131072, 2]), x1 shape: torch.Size([131072, 2]), rankD: 4
# Iteration: 0
# Iteration: 25

# %%
sample_sizes = [int(2**i) for i in range(5, 18, 1)]
print(sample_sizes)

# %%
# Saved for default jax rng random seed = 0
# up to 262144 on 1 CPU core

costs = {
    'HROT_LR': {'samples': [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144], 
                'costs': [2.228696584701538,
                          2.0213658809661865,
                          2.0618531703948975,
                          2.0906310081481934,
                          2.141716241836548,
                          2.1837940216064453,
                          2.1899118423461914,
                          2.2110908031463623,
                          2.2189435958862305,
                          2.219464063644409,
                          2.2266440391540527,
                          2.22908353805542,
                          2.2276337146759033,
                          2.2236123085021973
                         ]},
    'Sinkhorn': {'samples': [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384], 
                 'costs': [2.2296247482299805,
                          2.027103900909424,
                          2.0592880249023438,
                           2.094829559326172,
                           2.1440699100494385,
                          2.1944239139556885,
                           2.197434902191162,
                           2.2157516479492188,
                           2.223651170730591,
                           2.2288155555725098]},
    'ProgOT': {'samples': [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384],
               'costs': [2.238234043121338,
                        2.037097215652466,
                         2.0720245838165283,
                        2.111593246459961,
                         2.162586212158203,
                         2.2134077548980713,
                         2.215949773788452,
                         2.2341694831848145,
                         2.2429375648498535,
                         2.247523546218872
                        ]}
}

# %%
# Plotting the results
plt.figure(figsize=(10, 6))

for method, data in costs.items():
    if data['samples']:
        plt.plot(data['samples'], data['costs'], marker='o', label=method)

plt.xlabel('Sample Size')
plt.ylabel('Cost')
plt.title('Method Costs over Sample Complexities')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
times = {'HROT_LR': {'samples': [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384,
                                32768, 65536
                                ], 
                'times': [3.667863368988037,
                          2.343808650970459,
                          3.0835752487182617,
                          7.239800453186035,
                          21.791643619537354,
                          38.646852016448975,
                          51.093364000320435,
                          81.64709401130676,
                          130.2639126777649,
                          193.57822179794312,
                          383.44355726242065,
                          664.1615333557129
                         ]},
}

'''
'HROT_LR': {'samples': [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384], 
                'times': [3.667863368988037,
                          2.343808650970459,
                          3.0835752487182617,
                          7.239800453186035,
                          21.791643619537354,
                          38.646852016448975,
                          51.093364000320435,
                          81.64709401130676,
                          130.2639126777649,
                          193.57822179794312
                         ]},
                         
'Sinkhorn': {'samples': [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384], 
                'times': [0.1680617332458496,
                          0.1831061840057373,
                          0.6329329013824463,
                          0.1992018222808838,
                          0.22551584243774414,
                          0.3622288703918457,
                          0.9723002910614014,
                          4.914999961853027,
                          20.02446484565735,
                          89.86061763763428
                         ]},
                         
                         '''

# %%
# Plotting the results
plt.figure(figsize=(10, 6))

for method, data in times.items():
    if data['samples']:
        plt.plot(data['samples'], data['times'], marker='o', label=method)

plt.xlabel('Sample Size')
plt.ylabel('Runtime')
plt.title('Runtimes over Sample Complexities')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig('hrot_runtime.png', dpi=300)

plt.show()

# %%
'''
for n in sample_sizes:
    
    print(f'Current sample size: {n}')
    
    X, Y = ret_pts(experiment, n_points = n)
    
    # Define pairwise Dist Mat
    _X, _Y = torch.tensor(np.array(X)).type(torch.DoubleTensor).to(device), \
                        torch.tensor(np.array(Y)).type(torch.DoubleTensor).to(device)
    C = torch.cdist( _X, _Y ) ** p
    rank_schedule = [ K, int( n / K ) ] # Total of (1+K) runs of low-rank OT req'd
    
    # Full-rank cost matrix
    hrot = HR_OT.HierarchicalRefinementOT(C, \
                                  rank_schedule, \
                                  base_rank=1)
    P = hrot.run(return_as_coupling=True)
    cost_hrot = hrot.compute_OT_cost()
    cost_list_hrot.append(cost_hrot)
    #plot_proj(P)

    # Low-rank cost matrix
    hrot_lr = HR_OT.HierarchicalRefinementOT.init_from_point_clouds(_X, _Y, \
                                  rank_schedule, base_rank=1)
    P = hrot_lr.run(return_as_coupling=True)
    #plot_proj(P)
    cost_hrot_lr = hrot_lr.compute_OT_cost()
    cost_list_hrot_lr.append(cost_hrot_lr)
    
    #Sinkhorn Sol'n
    geom = Geometry( C.cpu().numpy() )
    ot_problem = linear_problem.LinearProblem(geom)
    solver = sinkhorn.Sinkhorn()
    ot_solution = solver(ot_problem)
    P_sinkhorn = ot_solution.matrix
    #plot_proj(np.array(P_sinkhorn))
    cost_sink = ( C.cpu().numpy() * P_sinkhorn ).sum()
    cost_list_sink.append(cost_sink)

    # ProgOT Sol'n
    x_train, y_train = X, Y
    alphas = progot.get_alpha_schedule("exp", num_steps=K)
    out = run_progot(X, Y, \
                     cost_fn, alphas=alphas, \
                     epsilons=None)
    P_progOT_default = out.get_output(-1).matrix
    #plot_proj(np.array(P_progOT_default))
    cost_progOT = ( C.cpu().numpy() * P_progOT_default ).sum()
    cost_list_progOT.append(cost_progOT)
    
    print(f'cost HROT: { cost_hrot.item() }, cost HROT-LR: { cost_hrot_lr.item() \
                                                }, cost Sink: { cost_sink }, cost progOT: { cost_progOT }')


'''
